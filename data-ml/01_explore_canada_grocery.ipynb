# %%
import pandas as pd

path = "raw/canada_grocery_nutrition_5000.csv"
df = pd.read_csv(path)

df.head()
# Out:
#            product_name           store         brand        category  \
# 0                 Bacon             IGA    Maple Leaf  Meat & Seafood
# 1  Romaine Lettuce 250g   Costco Canada     Coca-Cola         Produce
# 2       Oatmeal Cookies  Walmart Canada        Nestlé          Snacks
# 3         Turkey Breast         Longo's       PepsiCo  Meat & Seafood
# 4      Corn Flakes 250g         Loblaws  PC Blue Menu          Pantry
#
#        sub_category            food_type      veg_nonveg  calories  protein  \
# 0              Pork      Ultra-Processed  Non-Vegetarian     233.2     25.5
# 1        Vegetables  Minimally Processed      Vegetarian      69.2      3.7
# 2           Cookies  Minimally Processed      Vegetarian     506.8      5.5
# 3           Poultry      Ultra-Processed  Non-Vegetarian     234.7     25.2
# 4  Breakfast Cereal                Fresh      Vegetarian     406.6     12.6
#
#    carbs  ...  fiber  sodium  saturated_fat  trans_fat  cholesterol  \
# ...

# %%
df.shape
# Out:
# (4900, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4900 entries, 0 to 4899
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_name       4900 non-null   object
#  1   store              4900 non-null   object
#  2   brand              4900 non-null   object
#  3   category           4900 non-null   object
#  4   sub_category       4900 non-null   object
#  5   food_type          4900 non-null   object
#  6   veg_nonveg         4900 non-null   object
#  7   calories           4900 non-null   float64
#  8   protein            4900 non-null   float64
#  9   carbs              4900 non-null   float64
#  10  fat                4900 non-null   float64
#  11  sugar              4900 non-null   float64
#  12  fiber              4900 non-null   float64
#  13  sodium             4900 non-null   int64
#  14  saturated_fat      4900 non-null   float64
#  15  trans_fat          4900 non-null   float64
# ...

# %%
df.columns.tolist()
# Out:
# ['product_name',
#  'store',
#  'brand',
#  'category',
#  'sub_category',
#  'food_type',
#  'veg_nonveg',
#  'calories',
#  'protein',
#  'carbs',
#  'fat',
#  'sugar',
#  'fiber',
#  'sodium',
#  'saturated_fat',
#  'trans_fat',
#  'cholesterol',
#  'price_per_gram',
#  'price_per_serving',
#  'price_per_100g',
#  'FPro',
#  'nutriscore']

# %%
df.describe().T
# Out:
#                     count        mean         std     min       25%       50%  \
# calories           4900.0  234.756612  160.288122  0.0000   78.7000  230.2000
# protein            4900.0   10.283408    8.158615  0.0000    3.6000    8.7000
# carbs              4900.0   26.093306   20.396379  0.0000    8.3000   19.9000
# fat                4900.0   13.495816   12.200804  0.0000    1.4000   11.4000
# sugar              4900.0   10.659286    8.392049  0.0000    4.1000    9.7000
# fiber              4900.0    2.997571    2.972886  0.0000    0.0000    2.6000
# sodium             4900.0  749.603469  429.552928  1.0000  379.0000  750.5000
# saturated_fat      4900.0    4.065000    4.762532  0.0000    0.4000    2.4000
# trans_fat          4900.0    0.428988    0.448302  0.0000    0.0900    0.1800
# cholesterol        4900.0   26.336939   45.390885  0.0000    6.0000   12.0000
# price_per_gram     4900.0    0.008747    0.005220  0.0008    0.0048    0.0076
# ...

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# product_name         0.0
# store                0.0
# FPro                 0.0
# price_per_100g       0.0
# price_per_serving    0.0
# price_per_gram       0.0
# cholesterol          0.0
# trans_fat            0.0
# saturated_fat        0.0
# sodium               0.0
# fiber                0.0
# sugar                0.0
# fat                  0.0
# carbs                0.0
# protein              0.0
# calories             0.0
# veg_nonveg           0.0
# food_type            0.0
# sub_category         0.0
# category             0.0
# brand                0.0
# nutriscore           0.0
# dtype: float64
